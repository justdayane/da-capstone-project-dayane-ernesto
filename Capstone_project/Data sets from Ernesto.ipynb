# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/nestocr/Documents/DataAnalytics_BootCamp/da-capstone-project-dayane-ernesto/Ernestos_finds/levels-of-consumption/data/SA_0000001400.csv")

# %%
df
# Out:
#              Id  IndicatorCode SpatialDimension SpatialDimensionValueCode  \
# 0        933255  SA_0000001400          COUNTRY                       FIN
# 1        933909  SA_0000001400          COUNTRY                       PER
# 2        934148  SA_0000001400          COUNTRY                       ARM
# 3        934196  SA_0000001400          COUNTRY                       ESP
# 4        934198  SA_0000001400          COUNTRY                       LBR
# ...         ...            ...              ...                       ...
# 50433  10007014  SA_0000001400          COUNTRY                       THA
# 50434  10007157  SA_0000001400          COUNTRY                       BWA
# 50435  10007553  SA_0000001400          COUNTRY                       SVK
# 50436  10007738  SA_0000001400          COUNTRY                       BOL
# 50437  10007927  SA_0000001400          COUNTRY                       SUR
#
#       ParentLocationCode   ParentLocation TimeDimension  TimeDim  \
# ...
