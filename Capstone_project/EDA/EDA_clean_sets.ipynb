# %%
import pandas as pd
import plotly.express as px
import seaborn as sns
import plotly as plt

# %% [raw]
# Maps showing percent of prevalence (adjust column name) per age / country / year - Done.
# Bar charts showing consumption / prevalence per country / year (age is still aggregated value) - done for now.
#
#
# Exploration - list goals, hypothesis or questions:
# Cluster countries: 4 - check countries for each in Exploration Data sets
# Single countries for analysis: "Germany", "Italy", "Albania", "Czechia", "Ireland" (explore more with map graphs)
# Age groups: GenZ, Millenials, GenX (file gen_gap_2019) - explore different years with line / bar charts
# Explore the reasons why one generation is drinking more / less than the other - include articles, news from those years to support our findings.
#
# Working title of the final project: Alcohol Consumption in Europe, is the new generation actually drinking less?
#
# Which story are we gonna tell? (Ernesto is on it)

# %%
df = pd.read_csv(
    "/Users/dayaneribeiro/Documents/Spiced/da-capstone-project-dayane-ernesto/Cleaned Sets/abstention_and_prevalence_2005-2020.csv"
)
df

# prevalence: percentage of the population that has AUD (alcohol use disorder)
# Out:
#              location         sex          age  year  precent_of_prevalence  \
# 0             Albania        male  15-19 years  2005               0.009183
# 1             Albania      female  15-19 years  2005               0.006313
# 2             Albania  both sexes  15-19 years  2005               0.007746
# 3             Albania        male  20-24 years  2005               0.025058
# 4             Albania      female  20-24 years  2005               0.018224
# ...               ...         ...          ...   ...                    ...
# 15043  United Kingdom      female  35-39 years  2023               0.020648
# 15044  United Kingdom  both sexes  35-39 years  2023               0.049123
# 15045  United Kingdom        male  40-44 years  2023               0.078855
# 15046  United Kingdom      female  40-44 years  2023               0.019155
# 15047  United Kingdom  both sexes  40-44 years  2023               0.048010
#
# ...

# %%
df1 = pd.read_csv("/Users/dayaneribeiro/Documents/Spiced/da-capstone-project-dayane-ernesto/Cleaned Sets/consumption_and_prevalence_2005-2020.csv")
df1
# Out:
#             location          age  year  precent_of_prevalence  \
# 0            Albania  15-19 years  2005               0.007746
# 1            Albania  20-24 years  2005               0.021565
# 2            Albania  25-29 years  2005               0.027626
# 3            Albania  30-34 years  2005               0.028825
# 4            Albania  35-39 years  2005               0.025798
# ...              ...          ...   ...                    ...
# 5011  United Kingdom  20-24 years  2023               0.040710
# 5012  United Kingdom  25-29 years  2023               0.047753
# 5013  United Kingdom  30-34 years  2023               0.048562
# 5014  United Kingdom  35-39 years  2023               0.049123
# 5015  United Kingdom  40-44 years  2023               0.048010
#
#       pre_upper_bound  pre_lower_bound  consumption_in_liters
# 0            0.012591         0.004332                4.54992
# 1            0.033490         0.012558                4.54992
# ...

# %%
df1["precent_of_prevalence"] = df1["precent_of_prevalence"] * 100
df1.head()
# Out:
#   location          age  year  precent_of_prevalence  pre_upper_bound  \
# 0  Albania  15-19 years  2005               0.774575         0.012591
# 1  Albania  20-24 years  2005               2.156544         0.033490
# 2  Albania  25-29 years  2005               2.762616         0.038303
# 3  Albania  30-34 years  2005               2.882462         0.043374
# 4  Albania  35-39 years  2005               2.579800         0.036498
#
#    pre_lower_bound  consumption_in_liters
# 0         0.004332                4.54992
# 1         0.012558                4.54992
# 2         0.018784                4.54992
# 3         0.017788                4.54992
# 4         0.017049                4.54992

# %%
fig = px.choropleth(
    df1,
    #df1_clean.sort_values(by="NumericValue", ascending=False),
    locations="location", 
    locationmode="country names",        
    color="precent_of_prevalence",
    hover_name="location",
    #hover_data="year",
    #hover_data="age",
    color_continuous_scale="RdYlBu",
    #range_color=(0, 1),
    title="Alcohol Consumption by Country"
)
fig.update_geos(
    #scope="europe",
    projection_scale=2.5,
    center={"lat": 54, "lon": 15} 
)
fig.show()
# Out:
# /var/folders/s4/_zhd9zj1105fnq7y281mkzdc0000gn/T/ipykernel_2806/964913907.py:1: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(

# %%
df_age = df1[df1["age"] == "15-19 years"]

fig = px.choropleth(
    df_age,
    locations="location",
    locationmode="country names",
    color="precent_of_prevalence",
    hover_name="location",
    color_continuous_scale="RdYlBu",
    title="People with AUD by Country / Age"
)
fig.update_geos(
    #scope="europe",
    projection_scale=2.5,
    center={"lat": 54, "lon": 15} 
)

fig.show()
# Out:
# /var/folders/s4/_zhd9zj1105fnq7y281mkzdc0000gn/T/ipykernel_2806/2795842638.py:3: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(

# %%
fig = px.choropleth(
    df1,
    locations="location",
    locationmode="country names",
    color="precent_of_prevalence",
    hover_name="location",
    animation_frame="age", 
    color_continuous_scale="RdYlBu",
    title="Alcohol Consumption by Country and Age"
)
fig.update_geos(
    #scope="europe",
    projection_scale=2.5,
    center={"lat": 54, "lon": 15} 
)
#fig.layout.sliders[0].transition.duration = 2000
fig.show()
# Out:
# /var/folders/s4/_zhd9zj1105fnq7y281mkzdc0000gn/T/ipykernel_2806/2271379112.py:1: DeprecationWarning: The library used by the *country names* `locationmode` option is changing in an upcoming version. Country names in existing plots may not work in the new version. To ensure consistent behavior, consider setting `locationmode` to *ISO-3*.
#   fig = px.choropleth(

# %%
df2 = pd.read_csv("/Users/dayaneribeiro/Documents/Spiced/da-capstone-project-dayane-ernesto/Cleaned Sets/master_prevalence_2005_2023.csv")
df2
# Out:
#              location         sex          age  year  precent_of_prevalence  \
# 0             Albania        Male  15-19 years  2005               0.009183
# 1             Albania      Female  15-19 years  2005               0.006313
# 2             Albania  Both Sexes  15-19 years  2005               0.007746
# 3             Albania        Male  20-24 years  2005               0.025058
# 4             Albania      Female  20-24 years  2005               0.018224
# ...               ...         ...          ...   ...                    ...
# 15043  United Kingdom      Female  35-39 years  2023               0.020648
# 15044  United Kingdom  Both Sexes  35-39 years  2023               0.049123
# 15045  United Kingdom        Male  40-44 years  2023               0.078855
# 15046  United Kingdom      Female  40-44 years  2023               0.019155
# 15047  United Kingdom  Both Sexes  40-44 years  2023               0.048010
#
#        upper_bound  lower_bound
# ...

# %%
df2["precent_of_prevalence"] = df2["precent_of_prevalence"] * 100
df2.head()
# Out:
#   location         sex          age  year  precent_of_prevalence  upper_bound  \
# 0  Albania        Male  15-19 years  2005               0.918347     0.014542
# 1  Albania      Female  15-19 years  2005               0.631297     0.010442
# 2  Albania  Both Sexes  15-19 years  2005               0.774575     0.012591
# 3  Albania        Male  20-24 years  2005               2.505821     0.039093
# 4  Albania      Female  20-24 years  2005               1.822351     0.029243
#
#    lower_bound
# 0     0.005085
# 1     0.003289
# 2     0.004332
# 3     0.014484
# 4     0.010444

# %%
df2.rename(columns={"precent_of_prevalence": "AUD_percentage", "location": "country"}, inplace=True)
df2.head()
# Out:
#    country         sex          age  year  AUD_percentage  upper_bound  \
# 0  Albania        Male  15-19 years  2005        0.918347     0.014542
# 1  Albania      Female  15-19 years  2005        0.631297     0.010442
# 2  Albania  Both Sexes  15-19 years  2005        0.774575     0.012591
# 3  Albania        Male  20-24 years  2005        2.505821     0.039093
# 4  Albania      Female  20-24 years  2005        1.822351     0.029243
#
#    lower_bound
# 0     0.005085
# 1     0.003289
# 2     0.004332
# 3     0.014484
# 4     0.010444

# %%
age_groups = ["15-19 years", "20-24 years", "25-29 years", "30-34 years", "35-39 years"]

df_subset = df2[df2["age"].isin(age_groups)]

plt.figure(figsize=(10,6))
sns.lineplot(
    data=df_subset,
    x="year",
    y="AUD_percentage",
    hue="age"
)

plt.title("AUD prevalence per Age Group")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_plot = df2[
    (df2["year"] >= 2010) & 
    (df2["year"] <= 2020) &
    (df2["sex"] == "Both Sexes")
]

plt.figure(figsize=(10, 6))

sns.barplot(
    data=df_plot,
    x="year",
    y="precent_of_prevalence",
    hue="age"  
)

plt.title("AUD Percentage by Age Group Over Time")
plt.xlabel("Year")
plt.ylabel("AUD Percentage")

plt.legend(title="Age Group", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.show()

# %%
df3 = pd.read_csv("/Users/dayaneribeiro/Documents/Spiced/da-capstone-project-dayane-ernesto/Cleaned Sets/Consumption_in_Europe_2000-2020.csv")
df3
# Out:
#                              Title  Year Liters Pure Alcohol Consumed  \
# 0                       Azerbaijan  2008              0.6 [0.3 - 1.0]
# 1                         Portugal  2012            10.0 [8.4 - 11.7]
# 2                       Tajikistan  2020              0.8 [0.3 - 1.2]
# 3     Netherlands (Kingdom of the)  2008             9.4 [7.7 - 11.0]
# 4                         Portugal  2018            10.6 [9.0 - 12.2]
# ...                            ...   ...                          ...
# 1168                        Serbia  2020              7.9 [6.3 - 9.2]
# 1169                       Georgia  2005              5.4 [4.1 - 6.5]
# 1170                   Switzerland  2020             8.6 [7.2 - 10.1]
# 1171                       Czechia  2021           13.0 [11.2 - 14.7]
# 1172                    Azerbaijan  2017              0.6 [0.2 - 1.0]
#
#       NumericValue        Min        Max
# 0         0.568046   0.251125   0.964423
# 1        10.040000   8.401023  11.692693
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       1173 non-null   object
#  1   Year                          1173 non-null   int64
#  2   Liters Pure Alcohol Consumed  1173 non-null   object
#  3   Consumption                   1171 non-null   float64
#  4   Min                           1171 non-null   float64
#  5   Max                           1171 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 55.1+ KB

# %%
df3.rename(columns={"NumericValue": "Consumption", "Title": "Country"}, inplace=True)

# %%
df3.head()
# Out:
#                         Country  Year Liters Pure Alcohol Consumed  \
# 0                    Azerbaijan  2008              0.6 [0.3 - 1.0]
# 1                      Portugal  2012            10.0 [8.4 - 11.7]
# 2                    Tajikistan  2020              0.8 [0.3 - 1.2]
# 3  Netherlands (Kingdom of the)  2008             9.4 [7.7 - 11.0]
# 4                      Portugal  2018            10.6 [9.0 - 12.2]
#
#    Consumption       Min        Max
# 0     0.568046  0.251125   0.964423
# 1    10.040000  8.401023  11.692693
# 2     0.760516  0.340246   1.209908
# 3     9.350000  7.660837  10.963466
# 4    10.553597  8.961007  12.158488

# %%
sns.lineplot(
    data=df3[df3["Country"] == "Germany"],
    x="Year",
    y="Consumption",

)
# Out:
# <Axes: xlabel='Year', ylabel='Consumption'>

# %%
sns.lineplot(
    data=df3[df3["Country"] == "Ireland"],
    x="Year",
    y="Consumption",

)
# Out:
# <Axes: xlabel='Year', ylabel='Consumption'>

# %%
countries = ["Germany", "France", "Poland", "Czechia", "Ireland"]

df_subset = df3[df3["Country"].isin(countries)]

plt.figure(figsize=(10,6))
sns.lineplot(
    data=df_subset,
    x="Year",
    y="Consumption",
    hue="Country"
)

plt.title("Alcohol Consumption Over Time")
plt.show()

# %%
countries = ["Germany", "Italy", "Albania", "Czechia", "Ireland"]

df_subset = df3[df3["Country"].isin(countries)]

plt.figure(figsize=(10,6))
sns.lineplot(
    data=df_subset,
    x="Year",
    y="Consumption",
    hue="Country"
)

plt.title("Alcohol Consumption Over Time")
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
fig = px.line(
    df_subset,
    x="Year",
    y="Consumption",
    color="Country"
)

fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(
                    label=country,
                    method="update",
                    args=[{"visible": [c == country for c in df3["Country"].unique()]}]
                )
                for country in df3["Country"].unique()
            ],
            direction="down"
        )
    ]
)

fig.show()

# %% [markdown]
# analyse in a map the difference in consumption in Germany and Ireland, by generation (Gen_Z and Millenial) look at AUD
